// %% [markdown]
// <p style="font-weight:bold;"> <span style="font-size: 36px"> The Initial Migration Code </span> </p>

// %% [markdown]
// This copy contains the copy of the initial migration code. It is a necessary input to execute the first migration flow.

// %%
[Migration("20230523120744_InitialTypes")]
public class InitialTypes : Migration
{
    protected override void Up(MigrationBuilder migrationBuilder)
    {
        migrationBuilder.CreateTable(
            name: "AmountType",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                Parent = table.Column<string>(type: "nvarchar(max)", nullable: true),
                PeriodType = table.Column<int>(type: "int", nullable: false),
                Discriminator = table.Column<string>(type: "nvarchar(max)", nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Order = table.Column<int>(type: "int", nullable: false),
                ExternalId = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_AmountType", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "AocConfiguration",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Year = table.Column<int>(type: "int", nullable: false),
                Month = table.Column<int>(type: "int", nullable: false),
                AocType = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Novelty = table.Column<string>(type: "nvarchar(max)", nullable: true),
                DataType = table.Column<int>(type: "int", nullable: false),
                InputSource = table.Column<int>(type: "int", nullable: false),
                FxPeriod = table.Column<int>(type: "int", nullable: false),
                YcPeriod = table.Column<int>(type: "int", nullable: false),
                CdrPeriod = table.Column<int>(type: "int", nullable: false),
                ValuationPeriod = table.Column<int>(type: "int", nullable: false),
                RcPeriod = table.Column<int>(type: "int", nullable: false),
                Order = table.Column<int>(type: "int", nullable: false)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_AocConfiguration", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "CreditDefaultRate",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                CreditRiskRating = table.Column<string>(type: "nvarchar(max)", nullable: false),
                Year = table.Column<int>(type: "int", nullable: false),
                Month = table.Column<int>(type: "int", nullable: false),
                Values = table.Column<byte[]>(type: "varbinary(max)", nullable: true),
                Scenario = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_CreditDefaultRate", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "CreditRiskRating",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_CreditRiskRating", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "Currency",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_Currency", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "DataNode",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                Partition = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                ContractualCurrency = table.Column<string>(type: "nvarchar(max)", nullable: true),
                FunctionalCurrency = table.Column<string>(type: "nvarchar(max)", nullable: true),
                LineOfBusiness = table.Column<string>(type: "nvarchar(max)", nullable: true),
                ValuationApproach = table.Column<string>(type: "nvarchar(max)", nullable: false),
                OciType = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Discriminator = table.Column<string>(type: "nvarchar(max)", nullable: false),
                AnnualCohort = table.Column<int>(type: "int", nullable: true),
                LiabilityType = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Profitability = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Portfolio = table.Column<string>(type: "nvarchar(max)", nullable: true),
                YieldCurveName = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Partner = table.Column<string>(type: "nvarchar(max)", nullable: true),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_DataNode", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "DataNodeParameter",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Partition = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Year = table.Column<int>(type: "int", nullable: false),
                Month = table.Column<int>(type: "int", nullable: false),
                DataNode = table.Column<string>(type: "nvarchar(max)", nullable: false),
                Scenario = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Discriminator = table.Column<string>(type: "nvarchar(max)", nullable: false),
                LinkedDataNode = table.Column<string>(type: "nvarchar(max)", nullable: true),
                ReinsuranceCoverage = table.Column<double>(type: "float", nullable: true),
                PremiumAllocation = table.Column<double>(type: "float", nullable: true),
                CashFlowPeriodicity = table.Column<int>(type: "int", nullable: true),
                InterpolationMethod = table.Column<int>(type: "int", nullable: true),
                EconomicBasisDriver = table.Column<string>(type: "nvarchar(max)", nullable: true),
                ReleasePattern = table.Column<byte[]>(type: "varbinary(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_DataNodeParameter", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "DataNodeState",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Partition = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                DataNode = table.Column<string>(type: "nvarchar(max)", nullable: false),
                Year = table.Column<int>(type: "int", nullable: false),
                Month = table.Column<int>(type: "int", nullable: false),
                State = table.Column<int>(type: "int", nullable: false),
                Scenario = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_DataNodeState", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "EconomicBasis",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_EconomicBasis", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "EstimateType",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                InputSource = table.Column<int>(type: "int", nullable: false),
                StructureType = table.Column<int>(type: "int", nullable: false),
                PeriodType = table.Column<int>(type: "int", nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Order = table.Column<int>(type: "int", nullable: false),
                ExternalId = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_EstimateType", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "ExchangeRate",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Currency = table.Column<string>(type: "nvarchar(max)", nullable: false),
                Year = table.Column<int>(type: "int", nullable: false),
                Month = table.Column<int>(type: "int", nullable: false),
                FxType = table.Column<int>(type: "int", nullable: false),
                FxToGroupCurrency = table.Column<double>(type: "float", nullable: false),
                Scenario = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_ExchangeRate", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "IfrsVariable",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                EconomicBasis = table.Column<string>(type: "nvarchar(max)", nullable: true),
                DataNode = table.Column<string>(type: "nvarchar(max)", nullable: true),
                AocType = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Novelty = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Partition = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Values = table.Column<byte[]>(type: "varbinary(max)", nullable: true),
                EstimateType = table.Column<string>(type: "nvarchar(max)", nullable: true),
                AmountType = table.Column<string>(type: "nvarchar(max)", nullable: true),
                AccidentYear = table.Column<int>(type: "int", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_IfrsVariable", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "IOActivity",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Username = table.Column<string>(type: "nvarchar(max)", nullable: true),
                StartDateTime = table.Column<DateTime>(type: "datetime2", nullable: false),
                EndDateTime = table.Column<DateTime>(type: "datetime2", nullable: false),
                Status = table.Column<int>(type: "int", nullable: false),
                Category = table.Column<string>(type: "nvarchar(max)", nullable: true),
                ExceptionMessage = table.Column<string>(type: "nvarchar(max)", nullable: true),
                ErrorMessages = table.Column<string>(type: "nvarchar(max)", nullable: true),
                WarningMessages = table.Column<string>(type: "nvarchar(max)", nullable: true),
                InfoMessages = table.Column<string>(type: "nvarchar(max)", nullable: true),
                SourceId = table.Column<Guid>(type: "uniqueidentifier", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_IOActivity", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "IOContent",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                CreationTime = table.Column<DateTime>(type: "datetime2", nullable: false),
                SerializedContent = table.Column<byte[]>(type: "varbinary(max)", nullable: true),
                Length = table.Column<long>(type: "bigint", nullable: true),
                Format = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Name = table.Column<string>(type: "nvarchar(max)", nullable: true),
                ContentType = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Discriminator = table.Column<string>(type: "nvarchar(max)", nullable: false),
                Directory = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Partition = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Source = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Content = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_IOContent", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "LiabilityType",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                Parent = table.Column<string>(type: "nvarchar(max)", nullable: true),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_LiabilityType", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "LineOfBusiness",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                Parent = table.Column<string>(type: "nvarchar(max)", nullable: true),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Order = table.Column<int>(type: "int", nullable: false)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_LineOfBusiness", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "Novelty",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Order = table.Column<int>(type: "int", nullable: false)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_Novelty", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "OciType",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_OciType", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "PartitionByReportingNode",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                ReportingNode = table.Column<string>(type: "nvarchar(max)", nullable: false)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_PartitionByReportingNode", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "PartitionByReportingNodeAndPeriod",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Year = table.Column<int>(type: "int", nullable: false),
                Month = table.Column<int>(type: "int", nullable: false),
                Scenario = table.Column<string>(type: "nvarchar(max)", nullable: true),
                ReportingNode = table.Column<string>(type: "nvarchar(max)", nullable: false)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_PartitionByReportingNodeAndPeriod", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "Partner",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_Partner", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "PartnerRating",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Partner = table.Column<string>(type: "nvarchar(max)", nullable: false),
                CreditRiskRating = table.Column<string>(type: "nvarchar(max)", nullable: false),
                Year = table.Column<int>(type: "int", nullable: false),
                Month = table.Column<int>(type: "int", nullable: false),
                Scenario = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_PartnerRating", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "Profitability",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_Profitability", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "ProjectionConfiguration",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                Shift = table.Column<int>(type: "int", nullable: false),
                TimeStep = table.Column<int>(type: "int", nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Order = table.Column<int>(type: "int", nullable: false)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_ProjectionConfiguration", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "RawVariable",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                DataNode = table.Column<string>(type: "nvarchar(max)", nullable: true),
                AocType = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Novelty = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Partition = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Values = table.Column<byte[]>(type: "varbinary(max)", nullable: true),
                EstimateType = table.Column<string>(type: "nvarchar(max)", nullable: true),
                AmountType = table.Column<string>(type: "nvarchar(max)", nullable: true),
                AccidentYear = table.Column<int>(type: "int", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_RawVariable", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "ReportingNode",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                Parent = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Currency = table.Column<string>(type: "nvarchar(max)", nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_ReportingNode", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "RiskDriver",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                Parent = table.Column<string>(type: "nvarchar(max)", nullable: true),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Order = table.Column<int>(type: "int", nullable: false)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_RiskDriver", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "Scenario",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_Scenario", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "StructureType",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true),
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_StructureType", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "ValuationApproach",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_ValuationApproach", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "VariableType",
            columns: table => new
            {
                SystemName = table.Column<string>(type: "nvarchar(16)", maxLength: 16, nullable: false),
                Parent = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Discriminator = table.Column<string>(type: "nvarchar(max)", nullable: false),
                DisplayName = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Order = table.Column<int>(type: "int", nullable: false)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_VariableType", x => x.SystemName);
            });

        migrationBuilder.CreateTable(
            name: "YieldCurve",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Currency = table.Column<string>(type: "nvarchar(max)", nullable: false),
                Year = table.Column<int>(type: "int", nullable: false),
                Month = table.Column<int>(type: "int", nullable: false),
                Scenario = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Name = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Values = table.Column<byte[]>(type: "varbinary(max)", nullable: true)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_YieldCurve", x => x.Id);
            });

        migrationBuilder.CreateTable(
            name: "YieldCurveReport",
            columns: table => new
            {
                Id = table.Column<Guid>(type: "uniqueidentifier", nullable: false),
                Currency = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Year = table.Column<int>(type: "int", nullable: false),
                Month = table.Column<int>(type: "int", nullable: false),
                Scenario = table.Column<string>(type: "nvarchar(max)", nullable: true),
                Index = table.Column<int>(type: "int", nullable: false),
                Value = table.Column<double>(type: "float", nullable: false)
            },
            constraints: table =>
            {
                table.PrimaryKey("PK_YieldCurveReport", x => x.Id);
            });
    }

    protected override void Down(MigrationBuilder migrationBuilder)
    {
        migrationBuilder.DropTable(
            name: "AmountType");

        migrationBuilder.DropTable(
            name: "AocConfiguration");

        migrationBuilder.DropTable(
            name: "CreditDefaultRate");

        migrationBuilder.DropTable(
            name: "CreditRiskRating");

        migrationBuilder.DropTable(
            name: "Currency");

        migrationBuilder.DropTable(
            name: "DataNode");

        migrationBuilder.DropTable(
            name: "DataNodeParameter");

        migrationBuilder.DropTable(
            name: "DataNodeState");

        migrationBuilder.DropTable(
            name: "EconomicBasis");

        migrationBuilder.DropTable(
            name: "EstimateType");

        migrationBuilder.DropTable(
            name: "ExchangeRate");

        migrationBuilder.DropTable(
            name: "IfrsVariable");

        migrationBuilder.DropTable(
            name: "IOActivity");

        migrationBuilder.DropTable(
            name: "IOContent");

        migrationBuilder.DropTable(
            name: "LiabilityType");

        migrationBuilder.DropTable(
            name: "LineOfBusiness");

        migrationBuilder.DropTable(
            name: "Novelty");

        migrationBuilder.DropTable(
            name: "OciType");

        migrationBuilder.DropTable(
            name: "PartitionByReportingNode");

        migrationBuilder.DropTable(
            name: "PartitionByReportingNodeAndPeriod");

        migrationBuilder.DropTable(
            name: "Partner");

        migrationBuilder.DropTable(
            name: "PartnerRating");

        migrationBuilder.DropTable(
            name: "Profitability");

        migrationBuilder.DropTable(
            name: "ProjectionConfiguration");

        migrationBuilder.DropTable(
            name: "RawVariable");

        migrationBuilder.DropTable(
            name: "ReportingNode");

        migrationBuilder.DropTable(
            name: "RiskDriver");

        migrationBuilder.DropTable(
            name: "Scenario");

        migrationBuilder.DropTable(
            name: "ValuationApproach");

        migrationBuilder.DropTable(
            name: "VariableType");

        migrationBuilder.DropTable(
            name: "YieldCurve");

        migrationBuilder.DropTable(
            name: "YieldCurveReport");
    }
}
