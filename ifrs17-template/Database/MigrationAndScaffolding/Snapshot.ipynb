// %% [markdown]
// <p style="font-weight:bold;"> <span style="font-size: 36px"> The Current Snapshot </span> </p>

// %% [markdown]
// Each time you produce a new migration, please copy and paste the snapshot code directly here. This must be the copy of the *most recent* migration snapshot.

// %%
using Microsoft.EntityFrameworkCore;
using Microsoft.EntityFrameworkCore.Infrastructure;
using Microsoft.EntityFrameworkCore.Metadata;

public class DbModelSnapshot : ModelSnapshot
{
    protected override void BuildModel(ModelBuilder modelBuilder)
    {
        modelBuilder
            .HasAnnotation("ProductVersion", "6.0.1")
            .HasAnnotation("Relational:MaxIdentifierLength", 128);

        SqlServerModelBuilderExtensions.UseIdentityColumns(modelBuilder, 1L, 1);

        modelBuilder.Entity("Submission_103+RawVariable", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<int?>("AccidentYear")
                    .HasColumnType("int");

                b.Property<string>("AmountType")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("AocType")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("DataNode")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("EstimateType")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Novelty")
                    .HasColumnType("nvarchar(max)");

                b.Property<Guid>("Partition")
                    .HasColumnType("uniqueidentifier");

                b.Property<byte[]>("Values")
                    .HasColumnType("varbinary(max)");

                b.HasKey("Id");

                b.ToTable("RawVariable");
            });

        modelBuilder.Entity("Submission_104+IfrsVariable", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<int?>("AccidentYear")
                    .HasColumnType("int");

                b.Property<string>("AmountType")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("AocType")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("DataNode")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("EconomicBasis")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("EstimateType")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Novelty")
                    .HasColumnType("nvarchar(max)");

                b.Property<Guid>("Partition")
                    .HasColumnType("uniqueidentifier");

                b.Property<double>("Value")
                    .HasColumnType("float");

                b.Property<double>("Value1")
                    .HasColumnType("float");

                b.Property<double>("Value10")
                    .HasColumnType("float");

                b.Property<double>("Value11")
                    .HasColumnType("float");

                b.Property<double>("Value12")
                    .HasColumnType("float");

                b.Property<double>("Value2")
                    .HasColumnType("float");

                b.Property<double>("Value3")
                    .HasColumnType("float");

                b.Property<double>("Value4")
                    .HasColumnType("float");

                b.Property<double>("Value5")
                    .HasColumnType("float");

                b.Property<double>("Value6")
                    .HasColumnType("float");

                b.Property<double>("Value7")
                    .HasColumnType("float");

                b.Property<double>("Value8")
                    .HasColumnType("float");

                b.Property<double>("Value9")
                    .HasColumnType("float");

                b.HasKey("Id");

                b.ToTable("IfrsVariable");
            });

        modelBuilder.Entity("Submission_155+IOActivity", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("Category")
                    .HasColumnType("nvarchar(max)");

                b.Property<DateTime>("EndDateTime")
                    .HasColumnType("datetime2");

                b.Property<string>("ErrorMessages")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("ExceptionMessage")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("InfoMessages")
                    .HasColumnType("nvarchar(max)");

                b.Property<Guid?>("SourceId")
                    .HasColumnType("uniqueidentifier");

                b.Property<DateTime>("StartDateTime")
                    .HasColumnType("datetime2");

                b.Property<int>("Status")
                    .HasColumnType("int");

                b.Property<string>("Username")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("WarningMessages")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("Id");

                b.ToTable("IOActivity");
            });

        modelBuilder.Entity("Submission_156+IOContent", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("ContentType")
                    .HasColumnType("nvarchar(max)");

                b.Property<DateTime>("CreationTime")
                    .HasColumnType("datetime2");

                b.Property<string>("Discriminator")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Format")
                    .HasColumnType("nvarchar(max)");

                b.Property<long?>("Length")
                    .HasColumnType("bigint");

                b.Property<string>("Name")
                    .HasColumnType("nvarchar(max)");

                b.Property<byte[]>("SerializedContent")
                    .HasColumnType("varbinary(max)");

                b.HasKey("Id");

                b.ToTable("IOContent");

                b.HasDiscriminator<string>("Discriminator").HasValue("IOContent");
            });

        modelBuilder.Entity("Submission_175+YieldCurveReport", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("Currency")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Index")
                    .HasColumnType("int");

                b.Property<int>("Month")
                    .HasColumnType("int");

                b.Property<string>("Scenario")
                    .HasColumnType("nvarchar(max)");

                b.Property<double>("Value")
                    .HasColumnType("float");

                b.Property<int>("Year")
                    .HasColumnType("int");

                b.HasKey("Id");

                b.ToTable("YieldCurveReport");
            });

        modelBuilder.Entity("Submission_62+AmountType", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("Discriminator")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("ExternalId")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Order")
                    .HasColumnType("int");

                b.Property<string>("Parent")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("PeriodType")
                    .HasColumnType("int");

                b.HasKey("SystemName");

                b.ToTable("AmountType");

                b.HasDiscriminator<string>("Discriminator").HasValue("AmountType");
            });

        modelBuilder.Entity("Submission_64+RiskDriver", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Order")
                    .HasColumnType("int");

                b.Property<string>("Parent")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("RiskDriver");
            });

        modelBuilder.Entity("Submission_65+EstimateType", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("ExternalId")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("InputSource")
                    .HasColumnType("int");

                b.Property<int>("Order")
                    .HasColumnType("int");

                b.Property<int>("PeriodType")
                    .HasColumnType("int");

                b.Property<int>("StructureType")
                    .HasColumnType("int");

                b.HasKey("SystemName");

                b.ToTable("EstimateType");
            });

        modelBuilder.Entity("Submission_66+Novelty", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Order")
                    .HasColumnType("int");

                b.HasKey("SystemName");

                b.ToTable("Novelty");
            });

        modelBuilder.Entity("Submission_67+VariableType", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("Discriminator")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Order")
                    .HasColumnType("int");

                b.Property<string>("Parent")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("VariableType");

                b.HasDiscriminator<string>("Discriminator").HasValue("VariableType");
            });

        modelBuilder.Entity("Submission_73+Scenario", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("Scenario");
            });

        modelBuilder.Entity("Submission_74+LineOfBusiness", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Order")
                    .HasColumnType("int");

                b.Property<string>("Parent")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("LineOfBusiness");
            });

        modelBuilder.Entity("Submission_75+Currency", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("Currency");
            });

        modelBuilder.Entity("Submission_76+EconomicBasis", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("EconomicBasis");
            });

        modelBuilder.Entity("Submission_77+ValuationApproach", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("ValuationApproach");
            });

        modelBuilder.Entity("Submission_78+LiabilityType", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Parent")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("LiabilityType");
            });

        modelBuilder.Entity("Submission_79+OciType", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("OciType");
            });

        modelBuilder.Entity("Submission_80+Profitability", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("Profitability");
            });

        modelBuilder.Entity("Submission_81+Partner", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("Partner");
            });

        modelBuilder.Entity("Submission_82+CreditRiskRating", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("CreditRiskRating");
            });

        modelBuilder.Entity("Submission_83+ReportingNode", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("Currency")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Parent")
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("ReportingNode");
            });

        modelBuilder.Entity("Submission_84+ProjectionConfiguration", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Shift")
                    .HasColumnType("int");

                b.Property<int>("TimeStep")
                    .HasColumnType("int");

                b.HasKey("SystemName");

                b.ToTable("ProjectionConfiguration");
            });

        modelBuilder.Entity("Submission_85+AocConfiguration", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("AocType")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("CdrPeriod")
                    .HasColumnType("int");

                b.Property<int>("DataType")
                    .HasColumnType("int");

                b.Property<int>("FxPeriod")
                    .HasColumnType("int");

                b.Property<int>("InputSource")
                    .HasColumnType("int");

                b.Property<int>("Month")
                    .HasColumnType("int");

                b.Property<string>("Novelty")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Order")
                    .HasColumnType("int");

                b.Property<int>("RcPeriod")
                    .HasColumnType("int");

                b.Property<int>("ValuationPeriod")
                    .HasColumnType("int");

                b.Property<int>("YcPeriod")
                    .HasColumnType("int");

                b.Property<int>("Year")
                    .HasColumnType("int");

                b.HasKey("Id");

                b.ToTable("AocConfiguration");
            });

        modelBuilder.Entity("Submission_86+ExchangeRate", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("Currency")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<double>("FxToGroupCurrency")
                    .HasColumnType("float");

                b.Property<int>("FxType")
                    .HasColumnType("int");

                b.Property<int>("Month")
                    .HasColumnType("int");

                b.Property<string>("Scenario")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Year")
                    .HasColumnType("int");

                b.HasKey("Id");

                b.ToTable("ExchangeRate");
            });

        modelBuilder.Entity("Submission_87+CreditDefaultRate", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("CreditRiskRating")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Month")
                    .HasColumnType("int");

                b.Property<string>("Scenario")
                    .HasColumnType("nvarchar(max)");

                b.Property<byte[]>("Values")
                    .HasColumnType("varbinary(max)");

                b.Property<int>("Year")
                    .HasColumnType("int");

                b.HasKey("Id");

                b.ToTable("CreditDefaultRate");
            });

        modelBuilder.Entity("Submission_88+YieldCurve", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("Currency")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Month")
                    .HasColumnType("int");

                b.Property<string>("Name")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Scenario")
                    .HasColumnType("nvarchar(max)");

                b.Property<byte[]>("Values")
                    .HasColumnType("varbinary(max)");

                b.Property<int>("Year")
                    .HasColumnType("int");

                b.HasKey("Id");

                b.ToTable("YieldCurve");
            });

        modelBuilder.Entity("Submission_89+PartnerRating", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("CreditRiskRating")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Month")
                    .HasColumnType("int");

                b.Property<string>("Partner")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Scenario")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Year")
                    .HasColumnType("int");

                b.HasKey("Id");

                b.ToTable("PartnerRating");
            });

        modelBuilder.Entity("Submission_91+PartitionByReportingNode", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("ReportingNode")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.HasKey("Id");

                b.ToTable("PartitionByReportingNode");
            });

        modelBuilder.Entity("Submission_92+PartitionByReportingNodeAndPeriod", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<int>("Month")
                    .HasColumnType("int");

                b.Property<string>("ReportingNode")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Scenario")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Year")
                    .HasColumnType("int");

                b.HasKey("Id");

                b.ToTable("PartitionByReportingNodeAndPeriod");
            });

        modelBuilder.Entity("Submission_93+DataNode", b =>
            {
                b.Property<string>("SystemName")
                    .HasMaxLength(16)
                    .HasColumnType("nvarchar(16)");

                b.Property<string>("ContractualCurrency")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Discriminator")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("DisplayName")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("FunctionalCurrency")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("LineOfBusiness")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("OciType")
                    .HasColumnType("nvarchar(max)");

                b.Property<Guid>("Partition")
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("ValuationApproach")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.HasKey("SystemName");

                b.ToTable("DataNode");

                b.HasDiscriminator<string>("Discriminator").HasValue("DataNode");
            });

        modelBuilder.Entity("Submission_97+DataNodeState", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("DataNode")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Month")
                    .HasColumnType("int");

                b.Property<Guid>("Partition")
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("Scenario")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("State")
                    .HasColumnType("int");

                b.Property<int>("Year")
                    .HasColumnType("int");

                b.HasKey("Id");

                b.ToTable("DataNodeState");
            });

        modelBuilder.Entity("Submission_98+DataNodeParameter", b =>
            {
                b.Property<Guid>("Id")
                    .ValueGeneratedOnAdd()
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("DataNode")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Discriminator")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Month")
                    .HasColumnType("int");

                b.Property<Guid>("Partition")
                    .HasColumnType("uniqueidentifier");

                b.Property<string>("Scenario")
                    .HasColumnType("nvarchar(max)");

                b.Property<int>("Year")
                    .HasColumnType("int");

                b.HasKey("Id");

                b.ToTable("DataNodeParameter");

                b.HasDiscriminator<string>("Discriminator").HasValue("DataNodeParameter");
            });

        modelBuilder.Entity("Submission_157+ExportFile", b =>
            {
                b.HasBaseType("Submission_156+IOContent");

                b.HasDiscriminator().HasValue("ExportFile");
            });

        modelBuilder.Entity("Submission_159+ImportFile", b =>
            {
                b.HasBaseType("Submission_156+IOContent");

                b.Property<string>("Directory")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Partition")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Source")
                    .HasColumnType("nvarchar(max)");

                b.HasDiscriminator().HasValue("ImportFile");
            });

        modelBuilder.Entity("Submission_160+ImportString", b =>
            {
                b.HasBaseType("Submission_156+IOContent");

                b.Property<string>("Content")
                    .HasColumnType("nvarchar(max)");

                b.HasDiscriminator().HasValue("ImportString");
            });

        modelBuilder.Entity("Submission_161+ImportDataSet", b =>
            {
                b.HasBaseType("Submission_156+IOContent");

                b.HasDiscriminator().HasValue("ImportDataSet");
            });

        modelBuilder.Entity("Submission_162+ImportStream", b =>
            {
                b.HasBaseType("Submission_156+IOContent");

                b.HasDiscriminator().HasValue("ImportStream");
            });

        modelBuilder.Entity("Submission_63+DeferrableAmountType", b =>
            {
                b.HasBaseType("Submission_62+AmountType");

                b.HasDiscriminator().HasValue("DeferrableAmountType");
            });

        modelBuilder.Entity("Submission_68+AocType", b =>
            {
                b.HasBaseType("Submission_67+VariableType");

                b.HasDiscriminator().HasValue("AocType");
            });

        modelBuilder.Entity("Submission_70+PnlVariableType", b =>
            {
                b.HasBaseType("Submission_67+VariableType");

                b.HasDiscriminator().HasValue("PnlVariableType");
            });

        modelBuilder.Entity("Submission_71+BsVariableType", b =>
            {
                b.HasBaseType("Submission_67+VariableType");

                b.HasDiscriminator().HasValue("BsVariableType");
            });

        modelBuilder.Entity("Submission_72+AccountingVariableType", b =>
            {
                b.HasBaseType("Submission_67+VariableType");

                b.HasDiscriminator().HasValue("AccountingVariableType");
            });

        modelBuilder.Entity("Submission_94+Portfolio", b =>
            {
                b.HasBaseType("Submission_93+DataNode");

                b.HasDiscriminator().HasValue("Portfolio");
            });

        modelBuilder.Entity("Submission_95+GroupOfContract", b =>
            {
                b.HasBaseType("Submission_93+DataNode");

                b.Property<int>("AnnualCohort")
                    .HasColumnType("int");

                b.Property<string>("LiabilityType")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Partner")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Portfolio")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("Profitability")
                    .HasColumnType("nvarchar(max)");

                b.Property<string>("YieldCurveName")
                    .HasColumnType("nvarchar(max)");

                b.HasDiscriminator().HasValue("GroupOfContract");
            });

        modelBuilder.Entity("Submission_99+InterDataNodeParameter", b =>
            {
                b.HasBaseType("Submission_98+DataNodeParameter");

                b.Property<string>("LinkedDataNode")
                    .IsRequired()
                    .HasColumnType("nvarchar(max)");

                b.Property<double>("ReinsuranceCoverage")
                    .HasColumnType("float");

                b.HasDiscriminator().HasValue("InterDataNodeParameter");
            });

        modelBuilder.Entity("Submission_99+SingleDataNodeParameter", b =>
            {
                b.HasBaseType("Submission_98+DataNodeParameter");

                b.Property<int>("CashFlowPeriodicity")
                    .HasColumnType("int");

                b.Property<int>("InterpolationMethod")
                    .HasColumnType("int");

                b.Property<double>("PremiumAllocation")
                    .HasColumnType("float");

                b.HasDiscriminator().HasValue("SingleDataNodeParameter");
            });

        modelBuilder.Entity("Submission_94+InsurancePortfolio", b =>
            {
                b.HasBaseType("Submission_94+Portfolio");

                b.HasDiscriminator().HasValue("InsurancePortfolio");
            });

        modelBuilder.Entity("Submission_94+ReinsurancePortfolio", b =>
            {
                b.HasBaseType("Submission_94+Portfolio");

                b.HasDiscriminator().HasValue("ReinsurancePortfolio");
            });

        modelBuilder.Entity("Submission_96+GroupOfInsuranceContract", b =>
            {
                b.HasBaseType("Submission_95+GroupOfContract");

                b.HasDiscriminator().HasValue("GroupOfInsuranceContract");
            });

        modelBuilder.Entity("Submission_96+GroupOfReinsuranceContract", b =>
            {
                b.HasBaseType("Submission_95+GroupOfContract");

                b.HasDiscriminator().HasValue("GroupOfReinsuranceContract");
            });
    }
}
